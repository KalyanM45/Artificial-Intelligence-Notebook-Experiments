# %%
import warnings
warnings.simplefilter('ignore')

import librosa
import numpy as np
import pandas as pd
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
file_path = '../Artifacts/UrbanSound8K/audio/fold5/6508-9-0-3.wav'

# %%
ipd.Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, sample_rate = librosa.load(file_path)
data
# Out:
# array([-0.03790573, -0.06705092, -0.06876993, ...,  0.1388888 ,
#         0.13909438,  0.14631495], dtype=float32)

# %% [markdown]
# * <b>Sample Rate</b>: The number of times the sound is sampled per second

# %%
sample_rate
# Out:
# 22050

# %%
librosa.display.waveshow(data, sr=sample_rate)

# %%
from scipy.io import wavfile as wav
wav_sample_rate, wav_data = wav.read(file_path)

# %%
wav_sample_rate
# Out:
# 44100

# %%
wav_data
# Out:
# array([[-1976, -1271],
#        [-2262, -1466],
#        [-2534, -1626],
#        ...,
#        [ 3882,  5416],
#        [ 3917,  5202],
#        [ 3904,  4925]], dtype=int16)

# %%
metadata = pd.read_csv("../Artifacts/UrbanSound8K/metadata/UrbanSound8K.csv")

# %%
metadata
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# ...

# %%
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64

# %% [markdown]
# # Data Preprocessing
